# %%
# ========================
# Week 1 Project - Climate Risk and Disaster Management
# Exploratory Data Analysis of FEMA Disaster Declarations
# ========================

# Step 1: Import Necessary Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 2: Load the Dataset
# Make sure to upload your dataset file (disaster_declarations_summaries.csv) in Google Colab
df = pd.read_csv("/content/DisasterDeclarationsSummaries.csv")

# Show first 5 rows
df.head()
# Out:
#    disasterNumber  ihProgramDeclared  iaProgramDeclared  paProgramDeclared  \
# 0               3                  0                  1                  1
# 1               1                  0                  1                  1
# 2               9                  0                  1                  1
# 3              11                  0                  1                  1
# 4               4                  0                  1                  1
#
#    hmProgramDeclared state           declarationDate  fyDeclared disasterType  \
# 0                  1    LA  1953-05-29T00:00:00.000Z        1953           DR
# 1                  1    GA  1953-05-02T00:00:00.000Z        1953           DR
# 2                  1    TX  1953-06-19T00:00:00.000Z        1953           DR
# 3                  1    NH  1953-07-02T00:00:00.000Z        1953           DR
# 4                  1    MI  1953-06-02T00:00:00.000Z        1953           DR
#
# ...

# %%
# Step 3.1: Dataset Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60191 entries, 0 to 60190
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   disasterNumber        60191 non-null  int64
#  1   ihProgramDeclared     60191 non-null  int64
#  2   iaProgramDeclared     60191 non-null  int64
#  3   paProgramDeclared     60191 non-null  int64
#  4   hmProgramDeclared     60191 non-null  int64
#  5   state                 60191 non-null  object
#  6   declarationDate       60191 non-null  object
#  7   fyDeclared            60191 non-null  int64
#  8   disasterType          60191 non-null  object
#  9   incidentType          60191 non-null  object
#  10  title                 60191 non-null  object
#  11  incidentBeginDate     60191 non-null  object
#  12  incidentEndDate       52093 non-null  object
#  13  disasterCloseOutDate  43530 non-null  object
#  14  declaredCountyArea    59992 non-null  object
# ...

# %%
# Step 3.2: Statistical Summary
df.describe(include="all")
# Out:
#         disasterNumber  ihProgramDeclared  iaProgramDeclared  \
# count     60191.000000       60191.000000       60191.000000
# unique             NaN                NaN                NaN
# top                NaN                NaN                NaN
# freq               NaN                NaN                NaN
# mean       2475.266402           0.166138           0.285408
# std        1378.885968           0.372207           0.451612
# min           1.000000           0.000000           0.000000
# 25%        1247.000000           0.000000           0.000000
# 50%        2802.000000           0.000000           0.000000
# 75%        3458.000000           0.000000           1.000000
# max        5382.000000           1.000000           1.000000
#
#         paProgramDeclared  hmProgramDeclared  state           declarationDate  \
# count        60191.000000       60191.000000  60191                     60191
# ...

# %%
# Step 3.3: Missing Values Check
df.isnull().sum()
# Out:
# disasterNumber              0
# ihProgramDeclared           0
# iaProgramDeclared           0
# paProgramDeclared           0
# hmProgramDeclared           0
# state                       0
# declarationDate             0
# fyDeclared                  0
# disasterType                0
# incidentType                0
# title                       0
# incidentBeginDate           0
# incidentEndDate          8098
# disasterCloseOutDate    16661
# declaredCountyArea        199
# placeCode                 199
# hash                        0
# lastRefresh                 0
# id                          0
# dtype: int64
